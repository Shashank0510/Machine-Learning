# %% [markdown]
# ML Forum -Dr.AIT

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
import pandas as pd
import numpy as np

# %%
bank=pd.read_csv("bank.csv")
bank.head()
# Out:
#    age          job  marital  education default  balance housing loan  \
# 0   30   unemployed  married    primary      no     1787      no   no
# 1   33     services  married  secondary      no     4789     yes  yes
# 2   35   management   single   tertiary      no     1350     yes   no
# 3   30   management  married   tertiary      no     1476     yes  yes
# 4   59  blue-collar  married  secondary      no        0     yes   no
#
#     contact  day month  duration  campaign  pdays  previous poutcome   y
# 0  cellular   19   oct        79         1     -1         0  unknown  no
# 1  cellular   11   may       220         1    339         4  failure  no
# 2  cellular   16   apr       185         1    330         1  failure  no
# 3   unknown    3   jun       199         4     -1         0  unknown  no
# 4   unknown    5   may       226         1     -1         0  unknown  no

# %%
b.shape
# Out:
# (4521, 17)

# %%
len(bank)
# Out:
# 4521

# %%
bank.age.mean()
# Out:
# 41.17009511170095

# %%
a=bank.age.min()
b=bank[bank.age==a]
b.marital.sort_index()
# Out:
# 503     single
# 1900    single
# 2780    single
# 3233    single
# Name: marital, dtype: object

# %%
b=bank
b['job'].unique()
# Out:
# array(['unemployed', 'services', 'management', 'blue-collar',
#        'self-employed', 'technician', 'entrepreneur', 'admin.', 'student',
#        'housemaid', 'retired', 'unknown'], dtype=object)

# %%
b.job.value_counts()
# Out:
# management       969
# blue-collar      946
# technician       768
# admin.           478
# services         417
# retired          230
# self-employed    183
# entrepreneur     168
# unemployed       128
# housemaid        112
# student           84
# unknown           38
# Name: job, dtype: int64

# %%
b=bank
b=b[b.marital=="married"]
(len(b)/len(bank))*100
# Out:
# 61.86684361866843

# %%
b=bank
b.duration.max()
# Out:
# 3025

# %%
b=bank
b=b[b.job=="unemployed"]
b.age.mean()
# Out:
# 40.90625

# %%
b.shape
# Out:
# (4522, 4538)

# %%
b=bank
s=b.default
s=s.map({'no': 0, 'yes':1})
s=list(s)
b['default_code']=s
b.head()
# Out:
#    age          job  marital  education default  balance housing loan  \
# 0   30   unemployed  married    primary      no     1787      no   no
# 1   33     services  married  secondary      no     4789     yes  yes
# 2   35   management   single   tertiary      no     1350     yes   no
# 3   30   management  married   tertiary      no     1476     yes  yes
# 4   59  blue-collar  married  secondary      no        0     yes   no
#
#     contact  day month  duration  campaign  pdays  previous poutcome   y  \
# 0  cellular   19   oct        79         1     -1         0  unknown  no
# 1  cellular   11   may       220         1    339         4  failure  no
# 2  cellular   16   apr       185         1    330         1  failure  no
# 3   unknown    3   jun       199         4     -1         0  unknown  no
# 4   unknown    5   may       226         1     -1         0  unknown  no
#
#    default_code
# 0             0
# 1             0
# 2             0
# 3             0
# 4             0

# %%
b=bank
b=b[b.default=="yes"]
b.head()
# Out:
#      age           job   marital education default  balance housing loan  \
# 48    32  entrepreneur    single   primary     yes     -849     yes  yes
# 71    42  entrepreneur  divorced  tertiary     yes        2     yes   no
# 124   51    management    single  tertiary     yes      -55     yes   no
# 132   43   blue-collar   married   unknown     yes     -715     yes   no
# 152   45    unemployed  divorced   primary     yes     -249     yes  yes
#
#       contact  day month  duration  campaign  pdays  previous poutcome   y  \
# 48   cellular    4   feb       204         1     -1         0  unknown  no
# 71    unknown    5   may       380         1     -1         0  unknown  no
# 124  cellular   11   may       281         2    266         6  failure  no
# 132   unknown   30   may        67         3     -1         0  unknown  no
# 152   unknown    1   jul        92         1     -1         0  unknown  no
#
#      default_code
# 48              1
# 71              1
# ...

# %%
b=bank
b[b.job=="unemployed"].education.value_counts()
# Out:
# secondary    68
# tertiary     32
# primary      26
# unknown       2
# Name: education, dtype: int64

# %%
b=bank
s=b.marital
s=s.map({'married': 'm', 'single':'s' , 'divorced':'d'})
s=list(s)
b['marital_code']=s
b.head()
# Out:
#    age          job  marital  education default  balance housing loan  \
# 0   30   unemployed  married    primary      no     1787      no   no
# 1   33     services  married  secondary      no     4789     yes  yes
# 2   35   management   single   tertiary      no     1350     yes   no
# 3   30   management  married   tertiary      no     1476     yes  yes
# 4   59  blue-collar  married  secondary      no        0     yes   no
#
#     contact  day month  duration  campaign  pdays  previous poutcome   y  \
# 0  cellular   19   oct        79         1     -1         0  unknown  no
# 1  cellular   11   may       220         1    339         4  failure  no
# 2  cellular   16   apr       185         1    330         1  failure  no
# 3   unknown    3   jun       199         4     -1         0  unknown  no
# 4   unknown    5   may       226         1     -1         0  unknown  no
#
#    default_code marital_code
# 0             0            m
# 1             0            m
# ...
