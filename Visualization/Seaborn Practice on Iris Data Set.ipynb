# %%
import seaborn as sns

# %%
df = sns.load_dataset("iris")

# %%
df.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
df.corr()
# Out:
#               sepal_length  sepal_width  petal_length  petal_width
# sepal_length      1.000000    -0.117570      0.871754     0.817941
# sepal_width      -0.117570     1.000000     -0.428440    -0.366126
# petal_length      0.871754    -0.428440      1.000000     0.962865
# petal_width       0.817941    -0.366126      0.962865     1.000000

# %%
sns.heatmap(df.corr())

# %%
sns.pairplot(data=df)

# %%
sns.jointplot(x="sepal_length",y="sepal_width",kind="hex",data=df)

# %%
sns.jointplot(x="sepal_length",y="petal_length",kind="hex",data=df)

# %%
sns.distplot(df['sepal_length'],bins=10)

# %%
sns.distplot(df['petal_length'],bins=10)

# %%
sns.countplot('species',data=df)

# %%
sns.countplot(y='species',data=df)

# %%
sns.barplot(x="species",y="petal_length",data=df)

# %%
sns.boxplot(x="species",y="petal_length",data=df)

# %%
sns.boxplot(data=df,orient='v')

# %%
sns.violinplot('petal_length','species',data=df,)
